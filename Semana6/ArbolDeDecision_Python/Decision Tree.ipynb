# %% [markdown]
# ## Algoritmo de Arbol de Decisión
#
# Alumno: Leonardo Neyra Ocaña
#
# UPAO 2018-10

# %%
#Importar paquetes
import random

# %%
# Nodo
class Nodo:
  def __init__ (self, x, y):
    self.x = x
    self.y = y
    self.ri = None
    self.rd = None

# %%
# Árbol
class Arbol:
  def insertar_2 (self, x, y, nodo):
    if (y <= nodo.y):
      if (nodo.ri is not None):
        self.insertar_2(x, y, nodo.ri)
      else:
        nodo.ri = Nodo(x, y)
        self.n = self.n + 1
    else:
      if (nodo.rd is not None):
        self.insertar_2(x, y, nodo.rd)
      else:
        nodo.rd = Nodo(x, y)
        self.n = self.n + 1

  def insertar (self, x, y):
    if self.r is None:
      self.r = Nodo(x, y)
      self.n = self.n + 1
    else:
      self.insertar_2(x, y, self.r)

  def mostrar_2 (self, nodo):
    if nodo is not None:
      self.mostrar_2(nodo.ri)
      print("Nodo: %d - Peso: %f" % (nodo.x, nodo.y))
      self.mostrar_2(nodo.rd)

  def mostrar (self):
    if self.r is not None:
      self.mostrar_2(self.r)

  def pesos(self, nodo):
    t = 1
    if (nodo == None):
      return 1
    else:
      t = t * pesos(self.r.ri)
      print("Totalizado: %f" % t)
    return t

  def calcular_pesos(self):
    return self.calcular_pesos(self.r)

  def __init__ (self):
    self.r = None
    self.n = 0

arbol = Arbol()

for i in range(1, 501):
  arbol.insertar(i, random.uniform(1, 99999999))
arbol.mostrar()
# Out:
# Nodo: 16 - Peso: 36781.861256
# Nodo: 94 - Peso: 37179.720352
# Nodo: 185 - Peso: 88111.292673
# Nodo: 165 - Peso: 193659.828475
# Nodo: 469 - Peso: 621051.014999
# Nodo: 379 - Peso: 809566.092404
# Nodo: 398 - Peso: 962405.542782
# Nodo: 408 - Peso: 1016814.138255
# Nodo: 287 - Peso: 1099174.268482
# Nodo: 111 - Peso: 1253611.254252
# Nodo: 118 - Peso: 1664006.150383
# Nodo: 269 - Peso: 1725901.735627
# Nodo: 188 - Peso: 1728519.116653
# Nodo: 350 - Peso: 1744571.598045
# Nodo: 261 - Peso: 1770281.625925
# Nodo: 317 - Peso: 2037166.593127
# Nodo: 52 - Peso: 2045358.324034
# Nodo: 221 - Peso: 2065724.742767
# Nodo: 203 - Peso: 2458417.224976
# Nodo: 323 - Peso: 2566674.171681
# Nodo: 457 - Peso: 2586724.927516
# Nodo: 419 - Peso: 2673013.890381
# Nodo: 309 - Peso: 2876130.739646
# Nodo: 84 - Peso: 3017666.807673
# Nodo: 107 - Peso: 3091338.622365
# Nodo: 10 - Peso: 3262227.495467
# Nodo: 238 - Peso: 3277658.817184
# Nodo: 141 - Peso: 3348180.577780
# Nodo: 68 - Peso: 3371075.532036
# ...
